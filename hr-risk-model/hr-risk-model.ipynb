# %% [markdown]
# <h1>Оглавление<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1">Описание проекта</a></span></li><li><span><a href="#Задача-1:-предсказание-уровня-удовлетворённости-сотрудника" data-toc-modified-id="Задача-1:-предсказание-уровня-удовлетворённости-сотрудника-2">Задача 1: предсказание уровня удовлетворённости сотрудника</a></span></li><li><span><a href="#1.1-Описание-данных" data-toc-modified-id="1.1-Описание-данных-3">1.1 Описание данных</a></span></li><li><span><a href="#1.2-Загрузка-данных" data-toc-modified-id="1.2-Загрузка-данных-4">1.2 Загрузка данных</a></span></li><li><span><a href="#1.3-Предобработка-данных" data-toc-modified-id="1.3-Предобработка-данных-5">1.3 Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#1.3.1-Датафрейм-train_job_satisfaction_rate" data-toc-modified-id="1.3.1-Датафрейм-train_job_satisfaction_rate-5.1">1.3.1 Датафрейм train_job_satisfaction_rate</a></span></li><li><span><a href="#1.3.2-Датафрейм-test_features" data-toc-modified-id="1.3.2-Датафрейм-test_features-5.2">1.3.2 Датафрейм test_features</a></span></li><li><span><a href="#1.3.3-Датафрейм-test_target_job_satisfaction_rate" data-toc-modified-id="1.3.3-Датафрейм-test_target_job_satisfaction_rate-5.3">1.3.3 Датафрейм test_target_job_satisfaction_rate</a></span></li></ul></li><li><span><a href="#1.4-Исследовательский-анализ-данных" data-toc-modified-id="1.4-Исследовательский-анализ-данных-6">1.4 Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#1.4.1-Датафрейм-train_job_satisfaction_rate" data-toc-modified-id="1.4.1-Датафрейм-train_job_satisfaction_rate-6.1">1.4.1 Датафрейм train_job_satisfaction_rate</a></span></li><li><span><a href="#1.4.2-Датафрейм-test_features" data-toc-modified-id="1.4.2-Датафрейм-test_features-6.2">1.4.2 Датафрейм test_features</a></span></li></ul></li><li><span><a href="#1.5-Корреляционный-анализ" data-toc-modified-id="1.5-Корреляционный-анализ-7">1.5 Корреляционный анализ</a></span><ul class="toc-item"><li><span><a href="#1.5.1-Для-датафрейма-train_job_satisfaction_rate" data-toc-modified-id="1.5.1-Для-датафрейма-train_job_satisfaction_rate-7.1">1.5.1 Для датафрейма train_job_satisfaction_rate</a></span></li><li><span><a href="#1.5.2-Для-датафрейма-test_features" data-toc-modified-id="1.5.2-Для-датафрейма-test_features-7.2">1.5.2 Для датафрейма test_features</a></span></li></ul></li><li><span><a href="#1.6-Обучение-модели" data-toc-modified-id="1.6-Обучение-модели-8">1.6 Обучение модели</a></span><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-8.1">Подготовка данных</a></span></li><li><span><a href="#Использование-пайплайна" data-toc-modified-id="Использование-пайплайна-8.2">Использование пайплайна</a></span></li><li><span><a href="#Рассчет-метрики-SMAPE-на-тестовой-выборке" data-toc-modified-id="Рассчет-метрики-SMAPE-на-тестовой-выборке-8.3">Рассчет метрики SMAPE на тестовой выборке</a></span></li><li><span><a href="#Анализ-важности-признаков" data-toc-modified-id="Анализ-важности-признаков-8.4">Анализ важности признаков</a></span></li></ul></li><li><span><a href="#1.7-Вывод" data-toc-modified-id="1.7-Вывод-9">1.7 Вывод</a></span></li><li><span><a href="#Задача-2:-предсказание-увольнения-сотрудника-из-компании" data-toc-modified-id="Задача-2:-предсказание-увольнения-сотрудника-из-компании-10">Задача 2: предсказание увольнения сотрудника из компании</a></span></li><li><span><a href="#2.1-Описание-данных" data-toc-modified-id="2.1-Описание-данных-11">2.1 Описание данных</a></span></li><li><span><a href="#2.2-Загрузка-данных" data-toc-modified-id="2.2-Загрузка-данных-12">2.2 Загрузка данных</a></span></li><li><span><a href="#2.3-Предобработка-данных" data-toc-modified-id="2.3-Предобработка-данных-13">2.3 Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#2.3.1-Датафрейм-train_quit" data-toc-modified-id="2.3.1-Датафрейм-train_quit-13.1">2.3.1 Датафрейм train_quit</a></span></li><li><span><a href="#2.3.2-Датафрейм-test_target_quit" data-toc-modified-id="2.3.2-Датафрейм-test_target_quit-13.2">2.3.2 Датафрейм test_target_quit</a></span></li></ul></li><li><span><a href="#2.4-Исследовательский-анализ-данных" data-toc-modified-id="2.4-Исследовательский-анализ-данных-14">2.4 Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#2.4.1-Датафрейм--train_quit" data-toc-modified-id="2.4.1-Датафрейм--train_quit-14.1">2.4.1 Датафрейм  train_quit</a></span></li><li><span><a href="#2.4.2-Датафрейм-test_features" data-toc-modified-id="2.4.2-Датафрейм-test_features-14.2">2.4.2 Датафрейм test_features</a></span></li></ul></li><li><span><a href="#2.5-Корреляционный-анализ" data-toc-modified-id="2.5-Корреляционный-анализ-15">2.5 Корреляционный анализ</a></span><ul class="toc-item"><li><span><a href="#Общий" data-toc-modified-id="Общий-15.1">Общий</a></span></li><li><span><a href="#Для-уволившихся-сотрудников" data-toc-modified-id="Для-уволившихся-сотрудников-15.2">Для уволившихся сотрудников</a></span></li><li><span><a href="#Для-работающих-сотрудников" data-toc-modified-id="Для-работающих-сотрудников-15.3">Для работающих сотрудников</a></span></li></ul></li><li><span><a href="#2.6-Портрет-уволившегося-сотрудника" data-toc-modified-id="2.6-Портрет-уволившегося-сотрудника-16">2.6 Портрет уволившегося сотрудника</a></span></li><li><span><a href="#2.7-Добавление-нового-признака" data-toc-modified-id="2.7-Добавление-нового-признака-17">2.7 Добавление нового признака</a></span></li><li><span><a href="#2.8-Обучение-модели" data-toc-modified-id="2.8-Обучение-модели-18">2.8 Обучение модели</a></span><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-18.1">Подготовка данных</a></span></li><li><span><a href="#Использование-пайплайна" data-toc-modified-id="Использование-пайплайна-18.2">Использование пайплайна</a></span></li><li><span><a href="#Рассчет-метрики-ROC_AUC-на-тестовой-выборке" data-toc-modified-id="Рассчет-метрики-ROC_AUC-на-тестовой-выборке-18.3">Рассчет метрики ROC_AUC на тестовой выборке</a></span></li><li><span><a href="#Анализ-важности-признаков" data-toc-modified-id="Анализ-важности-признаков-18.4">Анализ важности признаков</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-19">Общий вывод</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# HR-аналитики компании «Работа с заботой» помогают бизнесу оптимизировать управление персоналом: бизнес предоставляет данные, а аналитики предлагают, как избежать финансовых потерь и оттока сотрудников. В этом HR-аналитикам пригодится машинное обучение, с помощью которого получится быстрее и точнее отвечать на вопросы бизнеса.
#
# Компания предоставила данные с характеристиками сотрудников компании. Среди них — уровень удовлетворённости сотрудника работой в компании. Эту информацию получили из форм обратной связи: сотрудники заполняют тест-опросник, и по его результатам рассчитывается доля их удовлетворённости от 0 до 1, где 0 — совершенно неудовлетворён, 1 — полностью удовлетворён.
# Собирать данные такими опросниками не так легко: компания большая, и всех сотрудников надо сначала оповестить об опросе, а затем проследить, что все его прошли.
#
# Будет несколько задач. Первая — построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.
# Почему бизнесу это важно: удовлетворённость работой напрямую влияет на отток сотрудников. А предсказание оттока — одна из важнейших задач HR-аналитиков. Внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник.
#
# Вторая задача — построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.

# %% [markdown]
# ## Задача 1: предсказание уровня удовлетворённости сотрудника

# %% [markdown]
# ## 1.1 Описание данных

# %% [markdown]
# Для этой задачи заказчик предоставил три файла с данными:
#
# - Тренировочная выборка: `train_job_satisfaction_rate.csv`
# - Входные признаки тестовой выборки: `test_features.csv`
# - Целевой признак тестовой выборки: `test_target_job_satisfaction_rate.csv`
#
# Признаки, содержащиеся в предоставленных данных:
# - `id` — уникальный идентификатор сотрудника;
# - `dept` — отдел, в котором работает сотрудник;
# - `level` — уровень занимаемой должности;
# - `workload` — уровень загруженности сотрудника;
# - `employment_years` — длительность работы в компании (в годах);
# - `last_year_promo` — показывает, было ли повышение за последний год;
# - `last_year_violations` — показывает, нарушал ли сотрудник трудовой договор за последний год;
# - `supervisor_evaluation` — оценка качества работы сотрудника, которую дал руководитель;
# - `salary` — ежемесячная зарплата сотрудника;
# - `job_satisfaction_rate` — уровень удовлетворённости сотрудника работой в компании, целевой признак.

# %% [markdown]
# ## 1.2 Загрузка данных

# %%
pip install phik -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install shap -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade scikit-learn -q

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from scipy import stats as st
from sklearn.metrics import make_scorer, roc_auc_score
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import (LabelEncoder,
                                   OneHotEncoder, 
                                   OrdinalEncoder, 
                                   StandardScaler, 
                                   MinMaxScaler, 
                                   RobustScaler
                                  )
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.svm import SVR, SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.dummy import DummyRegressor

from phik import phik_matrix
from phik.report import plot_correlation_matrix
import shap

# %%
RANDOM_STATE = 42
TEST_SIZE = 0.25

# %%
train_job_satisfaction_rate = pd.read_csv('https://code.s3.yandex.net/datasets/train_job_satisfaction_rate.csv')
test_features = pd.read_csv('https://code.s3.yandex.net/datasets/test_features.csv')
test_target_job_satisfaction_rate = pd.read_csv('https://code.s3.yandex.net/datasets/test_target_job_satisfaction_rate.csv')

# %%
# Предварительный обзор данных
def data_overview(dataframes):
    for df in dataframes:
        print("=" * 100)
        print('Общая информация о датафрейме:')
        print(df.info())
        print("*" * 100)
        print(f'Статистическое описание числовых данных датафрейма:\n {df.describe()}')

# %%
data_overview([train_job_satisfaction_rate, test_features, test_target_job_satisfaction_rate])
# Out:
# ...
# Общая информация о датафрейме:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  3996 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB
# None
# ****************************************************************************************************
# ...

# %% [markdown]
# ## 1.3 Предобработка данных

# %%
# Функция для изучения датафрейма и получения общей информации о нем
def studying_dataframe(df):
    display(df.info(),
           df.head())

# %%
# Автоматизация проверки датафрейма на наличе дубликатов
# На входе функции подается комбинация столбцов, по которой можно проверить наличие НЕПОЛНЫХ явных дубликатов
def search_for_duplicates(df, column_combinations):
    
    # Проверка на наличие ПОЛНЫХ явных дубликатов
    print(f'Количество ПОЛНЫХ явных дубликатов: {df.duplicated().sum()}\n')
    
    # Проверка на наличие НЕПОЛНЫХ явных дубликатов
    if len(column_combinations) > 0:
        cout_of_dup = df[column_combinations].duplicated().sum()
        print(f'Количество НЕПОЛНЫХ явных дубликатов: {cout_of_dup}\n')
    
    # Проверка на наличие неявных дубликаов
    print(f'Проверка на неявные дубликаты:')
    if len(df.select_dtypes(exclude='number').columns.tolist()) > 0:
        for cat_col in df.select_dtypes(exclude='number').columns.tolist():
            print(f'- Для {cat_col}: {df[cat_col].unique().tolist()}')

# %% [markdown]
# ### 1.3.1 Датафрейм train_job_satisfaction_rate

# %% [markdown]
# Изучим датафрейм и общую информацию о нем.

# %%
studying_dataframe(train_job_satisfaction_rate)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  3996 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB
# None
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# ...

# %% [markdown]
# Все столбцы соответствуют змеиному стилю. Значения переменных также приведены к одному стилю - записаны с помощью нижнего регистра. Датафрейм в "эстетических" изменениях не нуждается. Во всех столбцах типы данных соответствуют содержащимся в них значениям.

# %% [markdown]
# Изучив общую информацию о датафрейме, мы обнаружили пропуски данных в столбцах `dept` и `level`. Посмотрим насколько высока доля данных с пропусками от общего числа наблюдений, чтобы понять нанесет ли ущерб заполнение этих пропусков модой (заполнение модой было выбрано, так как мы имеем дело с категориальными переменными).

# %%
# Выведем строки с пропусками
train_job_satisfaction_rate[(train_job_satisfaction_rate['dept'].isna()) | (train_job_satisfaction_rate['level'].isna())]
# Out:
#           id   dept   level workload  employment_years last_year_promo  \
# 1209  631073  sales     NaN   medium                 1              no
# 1469  416327  sales     NaN      low                 1              no
# 1526  694746    NaN  junior   medium                 5              no
# 1630  814624    NaN  junior   medium                 3              no
# 1633  475114    NaN  junior     high                 4              no
# 1745  135043  sales     NaN   medium                 1              no
# 2522  998838  sales     NaN   medium                 1              no
# 2781  497243    NaN  junior   medium                 1              no
# 2975  168668    NaN  junior      low                 3              no
# 3866  641150    NaN  junior      low                 3              no
#
#      last_year_violations  supervisor_evaluation  salary  \
# 1209                   no                      4   27600
# 1469                   no                      5   18000
# ...

# %%
# Определим доля данных с пропусками от общего числа наблюдений
(train_job_satisfaction_rate.loc[(train_job_satisfaction_rate['dept'].isna()) | (train_job_satisfaction_rate['level'].isna()), 'id'].count() 
 / train_job_satisfaction_rate.shape[0])
# Out:
# 0.0025

# %% [markdown]
# Доля данных с пропусками от общего числа наблюдений составляет всего 0.25%, что ничтожно мало и поэтому заполнение пропусков модой никак не должно навредить нашему анализу и исказить результат. В дальнейшем данное действие будет произведено в пайплайне с помощью метода SimpleImputer() и параметра strategy='most_frequent'.
# Удалять наблюдения из-за пропусков в двух из девяти признаков было бы нецелесообразно, так как мы потеряем большую часть полезной нам информации.

# %% [markdown]
# Проверим датафрейм на наличие дубликатов.

# %%
search_for_duplicates(train_job_satisfaction_rate, ['id'])
# Out:
# Количество ПОЛНЫХ явных дубликатов: 0
#
# Количество НЕПОЛНЫХ явных дубликатов: 0
#
# Проверка на неявные дубликаты:
# - Для dept: ['sales', 'hr', 'technology', 'purchasing', 'marketing', nan]
# - Для level: ['junior', 'middle', 'sinior', nan]
# - Для workload: ['medium', 'high', 'low']
# - Для last_year_promo: ['no', 'yes']
# - Для last_year_violations: ['no', 'yes']

# %% [markdown]
# Дубликаты отсутствуют. Можно заметить опечатку в "sinior". Заменим на "senior".

# %%
train_job_satisfaction_rate.loc[train_job_satisfaction_rate['level'] == 'sinior', 'level'] = 'senior'

# Проверка
train_job_satisfaction_rate['level'].unique()
# Out:
# array(['junior', 'middle', 'senior', nan], dtype=object)

# %% [markdown]
# ### 1.3.2 Датафрейм test_features

# %% [markdown]
# Изучим общую информацию о датафреме.

# %%
studying_dataframe(test_features)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB
# None
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# ...

# %% [markdown]
# Во всех столбцах типы данных соответствуют содержащимся в них значениям. Все столбцы соответствуют змеиному стилю. Значения переменных также приведены к одному стилю - записаны с помощью нижнего регистра. Проверим соответсвуют ли названия и порядок столбцов тестовой выборки названию и порядку столбцов тренировочной выборки.

# %%
if  train_job_satisfaction_rate.drop('job_satisfaction_rate', axis=1).columns.tolist() == test_features.columns.tolist():
    print("Названия столбцов одинаковы")
else:
    print("Названия столбцов различаются")
# Out:
# Названия столбцов одинаковы

# %% [markdown]
# Датафрейм в "эстетических" изменениях не нуждается.

# %% [markdown]
# Изучив общую информацию о датафрейме, мы обнаружили пропуски данных в столбцах dept и level. В дальнейшем заполним их с помощью метода SimpleImputer() и параметра strategy='most_frequent' в пайплайне.

# %% [markdown]
# Проверим датафрейм на наличие дубликатов.

# %%
search_for_duplicates(test_features, ['id'])
# Out:
# Количество ПОЛНЫХ явных дубликатов: 0
#
# Количество НЕПОЛНЫХ явных дубликатов: 0
#
# Проверка на неявные дубликаты:
# - Для dept: ['marketing', 'hr', 'sales', 'purchasing', 'technology', nan, ' ']
# - Для level: ['junior', 'middle', 'sinior', nan]
# - Для workload: ['medium', 'low', 'high', ' ']
# - Для last_year_promo: ['no', 'yes']
# - Для last_year_violations: ['no', 'yes']

# %% [markdown]
# Дубликаты отсутствуют. Однако, мы также обнаружили в категориальных столбцах `dept` и `workload` пропуски с не нестандартным значение Nan без определенного типа NoneType. Эти пропуски выражены '  '. В дальнейшем они также будут устранены в дальнейшем (при работе с пайплайном) с помощью заполнения модой.
#
# Также можно заметить опечатку в "sinior". Заменим на "senior".

# %%
test_features.loc[test_features['level'] == 'sinior', 'level'] = 'senior'

# Проверка
test_features['level'].unique()
# Out:
# array(['junior', 'middle', 'senior', nan], dtype=object)

# %% [markdown]
# ### 1.3.3 Датафрейм test_target_job_satisfaction_rate

# %%
studying_dataframe(test_target_job_satisfaction_rate)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB
# None
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08

# %% [markdown]
# Во всех столбцах типы данных соответствуют содержащимся в них значениям. Все столбцы соответствуют змеиному стилю. Пропуски отсутсвуют.

# %%
search_for_duplicates(test_target_job_satisfaction_rate, ['id'])
# Out:
# Количество ПОЛНЫХ явных дубликатов: 0
#
# Количество НЕПОЛНЫХ явных дубликатов: 0
#
# Проверка на неявные дубликаты:

# %% [markdown]
# Дубликаты отсутствуют.

# %% [markdown]
# ## 1.4 Исследовательский анализ данных

# %%
# Функция для распределения признаков на категориальные и количественные
def distribution_by_data_types(df):
    
    quantitative_columns = df.select_dtypes(include = 'number').columns.tolist()
    categorical_columns = df.select_dtypes(exclude = 'number').columns.tolist()
    
    return quantitative_columns, categorical_columns

# %%
# Функция для исследования количественного непрерывного признака
def research_quantitative_continuous_signs(df, col, target):
    
    sns.set(context='poster')
    sns.set(style='white')
    fig, axs = plt.subplots(1, 2, figsize=(18, 6))  

    # Построение гистограммы
    if target.strip() == "": 
        sns.histplot(x=col, data=df, ax=axs[0], palette='viridis', bins=20)
        axs[0].set_ylabel('Количество')
    else: # Если мы имеем дело с задачами бинарной классификации
        sns.histplot(x=col, data=df, ax=axs[0], palette='viridis', bins=20, hue=target, stat='density', common_norm=False)
        axs[0].set_ylabel('Плотность')
    axs[0].set_title('Гистограмма')

    # Построение ящика с усами
    sns.boxplot(x=col, data=df, ax=axs[1], palette='viridis')
    axs[1].set_title('Ящик с усами')

    # Заголовок для всего рисунка
    fig.suptitle(f'Распределение для столбца \'{col}\'', fontsize=16)

    # Показать графики
    plt.show()

    # Описание данных
    print(f'Описание данных для столбца \'{col}\':\n{df[col].describe()}')

# %%
# Функция для исследования количественного дискретного признака
def research_quantitative_discrete_signs(df, col):
    
    sns.set(context='poster', style='whitegrid')  
    plt.figure(figsize=(10, 6))  
    
    # Построение столбчатой диаграммы
    sns.countplot(data=df, x=col, palette='viridis')
    plt.title(f'Диаграмма для столбца \'{col}\'', fontsize=16)
    plt.ylabel('Количество', fontsize=14)
    plt.xlabel(col, fontsize=14)
    
    plt.show()

# %%
# Функция для исследования категориального признака
def research_categorical_signs(df, col):
    
    sns.set(context='poster')
    sns.set(style='white')
    plt.figure(figsize=(10, 6))
    
    sorted_df = df[col].value_counts().reset_index().rename(columns={'index': col, col: 'Количество'})
    
    # Построение столбчатой диаграммы
    sns.barplot(data=sorted_df, x=col, y='Количество', palette='viridis')
    plt.title(f'Диаграмма для столбца \'{col}\'', fontsize=16)
    plt.ylabel('Количество', fontsize=14)
    plt.xlabel(col, fontsize=14)
    plt.xticks(rotation=45)
    plt.show()

# %%
# Функция для проведения исследовательского анализа данных
def research_analysis(df, quantitative_continuous_columns, quantitative_discrete_columns, categorical_columns, target_col):
    
    # Исследование количественных непрерывных признаков
    for qua_cont_col in quantitative_continuous_columns:
        research_quantitative_continuous_signs(df, qua_cont_col, target_col)
    
    # Исследование количественных дискретных признаков
    for qua_dis_col in quantitative_discrete_columns:
        research_quantitative_discrete_signs(df, qua_dis_col)
    
    # Исследование категориальных признаков
    for cat_col in categorical_columns:
        research_categorical_signs(df, cat_col)

# %% [markdown]
# ### 1.4.1 Датафрейм train_job_satisfaction_rate

# %%
# Сделаем значения столбца 'id' индексами
train_job_satisfaction_rate = train_job_satisfaction_rate.set_index('id')
train_job_satisfaction_rate.head()
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 155278       sales  junior   medium                 2              no
# 653870          hr  junior     high                 2              no
# 184592       sales  junior      low                 1              no
# 171431  technology  junior      low                 4              no
# 693419          hr  junior   medium                 1              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# 155278                   no                      1   24000
# 653870                   no                      5   38400
# 184592                   no                      2   12000
# 171431                   no                      2   18000
# 693419                   no                      3   22800
#
#         job_satisfaction_rate
# id
# 155278                   0.58
# 653870                   0.76
# 184592                   0.11
# 171431                   0.37
# ...

# %%
que_col_names, cat_col_names = distribution_by_data_types(train_job_satisfaction_rate)
print(f'Количественные признаки: {que_col_names}\n\nКатегориальные признаки: {cat_col_names}')
# Out:
# Количественные признаки: ['employment_years', 'supervisor_evaluation', 'salary', 'job_satisfaction_rate']
#
# Категориальные признаки: ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']

# %% [markdown]
# 'employment_years' и 'supervisor_evaluation' - дискретные признаки.

# %%
qua_cont_col_names = ['salary', 'job_satisfaction_rate']
qua_dis_col_names = ['employment_years', 'supervisor_evaluation']
print(f'Количественные непрерывные признаки: {qua_cont_col_names}\n\nКоличественные дискретные признаки: {qua_dis_col_names}')
# Out:
# Количественные непрерывные признаки: ['salary', 'job_satisfaction_rate']
#
# Количественные дискретные признаки: ['employment_years', 'supervisor_evaluation']

# %%
research_analysis(train_job_satisfaction_rate, qua_cont_col_names, qua_dis_col_names, cat_col_names, ' ')
# Out:
# Описание данных для столбца 'salary':
# count     4000.000000
# mean     33926.700000
# std      14900.703838
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      98400.000000
# Name: salary, dtype: float64
# Описание данных для столбца 'job_satisfaction_rate':
# count    4000.000000
# mean        0.533995
# std         0.225327
# min         0.030000
# 25%         0.360000
# 50%         0.560000
# 75%         0.710000
# max         1.000000
# Name: job_satisfaction_rate, dtype: float64

# %% [markdown]
# Изучив результаты исследовательского анализа датафрейма **train_job_satisfaction_rate**, можно сказать следующее:
# - `salary` — аналогично предыдущим, признак имеет нормальное распределение, но с положительной ассиметрией. Ежемесячная зарплата сотрудника в среднем составляет 33926, по гистограмме (медиаонное) около 30000. Можно заметить некоторое количество выбросов - скорее всего это сотрудники занимающие высокие/руководящие должности. В удалении нет необходимости, так как это реальные люди (реальные наблюдения), и вполне нормально что людей с такими должностями много меньше других сотрудников, а их зарплата выше. Модель должна будет уметь их учитывать.
# - `job_satisfaction_rate` — признак, характеризующий уровень удовлетворённости сотрудника работой в компании, имеет нормальное распределение с двумя пиками - значения сконцентрированы около 0.4 и 0.7 (из 1). То есть количество людей, оценивающих уровень своей удовлетворенность в 0.4 и 0.7, превышает количество людей, оценивающих его какой-либо другой оценкой. В среднем уровень удовлетворенности составляет 0.5.
# - `employment_years` — людей, работающих в компании около 1 года, больше количества людей с любой другой продолжительностью работы. Сотрудников, работающих более 10 лет, нет.
# - `supervisor_evaluation` — чаще всего сотрудники получают оценку 4 по пятибалльной шкале, реже 3 и 5, совсем редко 2 и 1.
# - `dept` — отдел, в котором работает больше всего сотрудников - sales. За ним идет отдел technology с штатом работников, размер которого практически в два раза меньше sales. Меньше всего сотрудников в hr-отделе.
# - `level` — больше всего сотрудников с уровенем занимаемой должности junior и middle, меньше всего - sinior.
# - `workload` — сотрудников со средним (medium) уровнем загруженности больше всего, с высоким (high) меньше всего;
# - `last_year_promo` — согласно диаграмме, лишь единицы получили повышение за последний год.
# - `last_year_violations` — около 500 сотрудников нарушили трудовой договор за последний год, остальные 3500 являются добропорядочными работниками.

# %% [markdown]
# ### 1.4.2 Датафрейм test_features

# %%
# Сделаем значения столбца 'id' индексами
test_features = test_features.set_index('id')
test_features.head()
# Out:
#              dept   level workload  employment_years last_year_promo  \
# id
# 485046  marketing  junior   medium                 2              no
# 686555         hr  junior   medium                 1              no
# 467458      sales  middle      low                 5              no
# 418655      sales  middle      low                 6              no
# 789145         hr  middle   medium                 5              no
#
#        last_year_violations  supervisor_evaluation  salary
# id
# 485046                   no                      5   28800
# 686555                   no                      4   30000
# 467458                   no                      4   19200
# 418655                   no                      4   19200
# 789145                   no                      5   40800

# %%
que_col_names, cat_col_names = distribution_by_data_types(test_features)
print(f'Количественные признаки: {que_col_names}\n\nКатегориальные признаки: {cat_col_names}')
# Out:
# Количественные признаки: ['employment_years', 'supervisor_evaluation', 'salary']
#
# Категориальные признаки: ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']

# %% [markdown]
# 'employment_years' и 'supervisor_evaluation' - дискретные признаки.

# %%
qua_cont_col_names = ['salary']
qua_dis_col_names = ['employment_years', 'supervisor_evaluation']
print(f'Количественные непрерывные признаки: {qua_cont_col_names}\n\nКоличественные дискретные признаки: {qua_dis_col_names}')
# Out:
# Количественные непрерывные признаки: ['salary']
#
# Количественные дискретные признаки: ['employment_years', 'supervisor_evaluation']

# %%
research_analysis(test_features, qua_cont_col_names, qua_dis_col_names, cat_col_names, ' ')
# Out:
# Описание данных для столбца 'salary':
# count     2000.000000
# mean     34066.800000
# std      15398.436729
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      96000.000000
# Name: salary, dtype: float64

# %% [markdown]
# Результаты исследовательского анализа входных признаков тестовой выборки идентичны результатам исследовательского анализа входных признаков тренировочной выборки. Еще раз более подробно рассмотрим и сравним статистическое описание каждой из выборок.

# %%
train_job_satisfaction_rate.drop('job_satisfaction_rate', axis=1).describe().T
# Out:
#                         count        mean           std      min      25%  \
# employment_years       4000.0      3.7185      2.542513      1.0      2.0
# supervisor_evaluation  4000.0      3.4765      1.008812      1.0      3.0
# salary                 4000.0  33926.7000  14900.703838  12000.0  22800.0
#
#                            50%      75%      max
# employment_years           3.0      6.0     10.0
# supervisor_evaluation      4.0      4.0      5.0
# salary                 30000.0  43200.0  98400.0

# %%
test_features.describe().T
# Out:
#                         count        mean           std      min      25%  \
# employment_years       2000.0      3.6665      2.537222      1.0      1.0
# supervisor_evaluation  2000.0      3.5265      0.996892      1.0      3.0
# salary                 2000.0  34066.8000  15398.436729  12000.0  22800.0
#
#                            50%      75%      max
# employment_years           3.0      6.0     10.0
# supervisor_evaluation      4.0      4.0      5.0
# salary                 30000.0  43200.0  96000.0

# %% [markdown]
# Статистические описания тренировочной и тестовой выборок похожи - это хороший знак для модели машинного обучения. Похожесть этих описаний указывает на то, что данные, на которых модель обучается (тренировочная выборка), и данные, на которых модель тестируется (тестовая выборка), взяты из одного и того же распределения. А также означает, что оба эти датасета были собраны в одинаковых условиях, то есть никаких измненений в исследуемом процессе не произошло.

# %% [markdown]
# ## 1.5 Корреляционный анализ

# %% [markdown]
# ### 1.5.1 Для датафрейма train_job_satisfaction_rate

# %%
# Создаем список с наименованиями непрерывных признаков
interval_col_names, cat_col_names = distribution_by_data_types(train_job_satisfaction_rate)
interval_col_names
# Out:
# ['employment_years',
#  'supervisor_evaluation',
#  'salary',
#  'job_satisfaction_rate']

# %% [markdown]
# 'employment_years' и 'supervisor_evaluation' - дискретные признаки.

# %%
interval_col_names.remove('employment_years')
interval_col_names.remove('supervisor_evaluation')
interval_col_names
# Out:
# ['salary', 'job_satisfaction_rate']

# %%
# Рассчитаем корреляционную матрицу
phik_overview = phik_matrix(train_job_satisfaction_rate, interval_cols=interval_col_names)

# %%
# Визуализируем корреляционную матрицу
plot_correlation_matrix(phik_overview.values,
                        x_labels=phik_overview.columns,
                        y_labels=phik_overview.index,
                        vmin=0, vmax=1, color_map='BuPu',
                        title=r'correlation $\phi_K$',
                        fontsize_factor=1.5,
                        figsize=(20, 15))

# %% [markdown]
# Изучив корреляционную матрицу, можно выделить следующее:
# - целевой признак `job_satisfaction_rate` имеет **сильную** линейную зависимость от признака **supervisor_evaluation**. Коэффициент корреляции положительный, то есть чем выше оценка сотрудника, которую дал руководитель, тем выше уровень удовлетворенности сотрудника.

# %% [markdown]
# - также признак имеет **среднюю** линейную зависимость от **last_year_violations**, то есть от того, нарушал ли человек трудовой договор за последний год.

# %%
research_quantitative_continuous_signs(train_job_satisfaction_rate, 'job_satisfaction_rate', 'last_year_violations')
# Out:
# Описание данных для столбца 'job_satisfaction_rate':
# count    4000.000000
# mean        0.533995
# std         0.225327
# min         0.030000
# 25%         0.360000
# 50%         0.560000
# 75%         0.710000
# max         1.000000
# Name: job_satisfaction_rate, dtype: float64

# %% [markdown]
# Как можно заметить по распрделению, среди людей не нарушавших трудовой договор, превалируют более удовлетворенные работой сотрудники. Средняя оценка для этой категории работников лежит в диапозоне 0.6-0.8. А среди людей нарушивших трудовой договор - наоборот, средняя оценка удовлетворенности составляет около 0.18. Возможно, нарушение договора повлекли конфликт с руковдством, а затем низкую оценку уровня удовлетворенности. Но чем было спровоцировано это нарушение? Может именно неудовлетворенностью работой, ее условиями, которым не хватает какой-то гибкости, улучшения.

# %% [markdown]
# - линейная зависимость **отсутствует** между целевым признаком и **level**, **workload** и **dept**. При анализе важности признаков после создания и обучения модели, акцентируем на эти признаки особое внимание. Возможно их  удаление в дальнейшем повлечет за собой улучшения результатов работы модели.

# %% [markdown]
# - также наблюдается мультиколлинеарность - средняя линейная зависимость между **employment_years** и **level**, то есть чем дольше сотрудник работает в компании, тем более высокую должность он занимает.

# %% [markdown]
# ### 1.5.2 Для датафрейма test_features

# %%
# Создаем список с наименованиями непрерывных признаков
interval_col_names, cat_col_names = distribution_by_data_types(test_features)
interval_col_names
# Out:
# ['employment_years', 'supervisor_evaluation', 'salary']

# %% [markdown]
# 'employment_years' и 'supervisor_evaluation' - дискретные признаки.

# %%
interval_col_names.remove('employment_years')
interval_col_names.remove('supervisor_evaluation')
interval_col_names
# Out:
# ['salary']

# %%
# Рассчитаем корреляционную матрицу
phik_overview = phik_matrix(test_features, interval_cols=interval_col_names)

# Визуализируем корреляционную матрицу
plot_correlation_matrix(phik_overview.values,
                        x_labels=phik_overview.columns,
                        y_labels=phik_overview.index,
                        vmin=0, vmax=1, color_map='PuBu',
                        title=r'correlation $\phi_K$',
                        fontsize_factor=1.5,
                        figsize=(20, 15))

# %% [markdown]
# По проведенному анализу можно сказать следующее:
#
# И в тренировочном, и в тестовом датафрейме наблюдается мультиколлинерность, а точнее:
# - высокая линейная зависимость между **salary** и **level** и **workload**, то есть зарплата тем выше, чем выше уровень занимаемой должности сотрудника и уровень его загруженности.
# - также наблюдается средняя линейная зависимость между **employment_years** и **level**, то есть чем дольше сотрудник работает в компании, тем более высокую должность он занимает.

# %% [markdown]
# ## 1.6 Обучение модели

# %% [markdown]
# ### Подготовка данных

# %%
train_job_satisfaction_rate.head()
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 155278       sales  junior   medium                 2              no
# 653870          hr  junior     high                 2              no
# 184592       sales  junior      low                 1              no
# 171431  technology  junior      low                 4              no
# 693419          hr  junior   medium                 1              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# 155278                   no                      1   24000
# 653870                   no                      5   38400
# 184592                   no                      2   12000
# 171431                   no                      2   18000
# 693419                   no                      3   22800
#
#         job_satisfaction_rate
# id
# 155278                   0.58
# 653870                   0.76
# 184592                   0.11
# 171431                   0.37
# ...

# %% [markdown]
# После перевода в индекс столбца 'id' (но до удаления job_satisfaction_rate) необходимо проверить наличие новых дубликатов в данных, так как мы удалили часть лишних признаков, у нас могут появиться новые явные дубликаты: чем меньше признаков остаётся, тем выше шанс, что значения остальных признаков будут пересекаться. При этом ценности для модели такие наблюдения уже не принесут, поэтому стоит проверить дубликаты также в финальной версии таблицы.

# %%
search_for_duplicates(train_job_satisfaction_rate, [])
# Out:
# Количество ПОЛНЫХ явных дубликатов: 245
#
# Проверка на неявные дубликаты:
# - Для dept: ['sales', 'hr', 'technology', 'purchasing', 'marketing', nan]
# - Для level: ['junior', 'middle', 'senior', nan]
# - Для workload: ['medium', 'high', 'low']
# - Для last_year_promo: ['no', 'yes']
# - Для last_year_violations: ['no', 'yes']

# %% [markdown]
# Удалим полные явные дубликаты

# %%
train_job_satisfaction_rate = train_job_satisfaction_rate.drop_duplicates()
train_job_satisfaction_rate.duplicated().sum()
# Out:
# 0

# %%
X_train = train_job_satisfaction_rate.drop('job_satisfaction_rate', axis=1)
y_train = train_job_satisfaction_rate['job_satisfaction_rate']

# %%
num_columns, cat_columns = distribution_by_data_types(X_train)
print(f'Количественные признаки: {num_columns}\n\nКатегориальные признаки: {cat_columns}')
# Out:
# Количественные признаки: ['employment_years', 'supervisor_evaluation', 'salary']
#
# Категориальные признаки: ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']

# %% [markdown]
# - Количественные признаки будут закодированы с помощью StandardScaler/MinMaxScaler/RobustScaler/без кодировки
# - Категориальные признаки будут закодированы следующим образом:
#   - 'level' и'workload' с помощью OrdinalEncoder(), так как данные признаки являются ранговыми.
#   - Остальные категориальные признаки будут кодироваться с помощью OneHotEncoding().

# %%
# Разделим категориальные признаки в зависимости от способа кодирования
ohe_columns = ['dept', 'last_year_promo', 'last_year_violations']
ord_columns = ['level', 'workload']

# %%
display(num_columns,
       ohe_columns,
       ord_columns)
# Out:
# ['employment_years', 'supervisor_evaluation', 'salary']
# ['dept', 'last_year_promo', 'last_year_violations']
# ['level', 'workload']

# %% [markdown]
# Выбирать лучшую модель и проверять её качество будем на основе метрики — SMAPE (англ. symmetric mean absolute percentage error, «симметричное среднее абсолютное процентное отклонение»).

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Создание метрики
def smape_func(y_true, y_pred):
    numerator = np.abs(y_true - y_pred)
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2.0
    return np.mean(numerator / denominator) * 100

smape_score = make_scorer(smape_func, greater_is_better = False)

# %% [markdown]
# ### Использование пайплайна

# %%
# создаём пайплайн для подготовки признаков из списка ohe_columns: заполнение пропусков и OHE-кодирование
# SimpleImputer + OHE
ohe_pipe = Pipeline(
    [('simpleImputer_ohe_NoneType', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('simpleImputer_ohe_str', SimpleImputer(missing_values=' ', strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
    ]
    )

# %%
# создаём пайплайн для подготовки признаков из списка ord_columns: заполнение пропусков и Ordinal-кодирование
# SimpleImputer + OE
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[
                    ['junior', 'middle', 'sinior'], 
                    ['low', 'medium', 'high']
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %%
# создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %%
# создаём итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', LinearRegression())
])

# %% [markdown]
# Перед нами стоит задача регресии, так как целевой признак является непрерывой величиной.

# %%
param_grid = [
    # словарь для модели DecisionTreeRegressor()
    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 20),
        'models__max_features': range(2, 20),
        'models__min_samples_split': range(2, 20),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']  
    },
    
    # словарь для модели LinearRegression()
    {
        'models': [LinearRegression()],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']  
    },
    
    # словарь для модели SVR()
    {
        'models': [SVR()],
        'models__kernel' : ['rbf','sigmoid', 'linear', 'poly'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']  
    }
]

randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring=smape_score,
    random_state=RANDOM_STATE,
    n_jobs=-1
)

randomized_search.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print('Метрика лучшей модели, полученная при кросс-валидации:', abs(randomized_search.best_score_))
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe_NoneType',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('simpleImputer_ohe_str',
#                                                                    SimpleImputer(missing_values=' ',
#                                                                                  strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
# ...

# %% [markdown]
# ### Рассчет метрики SMAPE на тестовой выборке

# %% [markdown]
# Посчитаем метрику SMAPE на предоставленном нам датафрейме test_features.csv с тестовыми входными признаками.

# %%
test_features.head()
# Out:
#              dept   level workload  employment_years last_year_promo  \
# id
# 485046  marketing  junior   medium                 2              no
# 686555         hr  junior   medium                 1              no
# 467458      sales  middle      low                 5              no
# 418655      sales  middle      low                 6              no
# 789145         hr  middle   medium                 5              no
#
#        last_year_violations  supervisor_evaluation  salary
# id
# 485046                   no                      5   28800
# 686555                   no                      4   30000
# 467458                   no                      4   19200
# 418655                   no                      4   19200
# 789145                   no                      5   40800

# %%
test_features.shape
# Out:
# (2000, 8)

# %%
test_target_job_satisfaction_rate = test_target_job_satisfaction_rate.set_index('id')
test_target_job_satisfaction_rate.head()
# Out:
#         job_satisfaction_rate
# id
# 130604                   0.74
# 825977                   0.75
# 418490                   0.60
# 555320                   0.72
# 826430                   0.08

# %%
test_target_job_satisfaction_rate.shape
# Out:
# (2000, 1)

# %%
# Лучшая модель
best_model = randomized_search.best_estimator_.named_steps['models']
best_model
# Out:
# DecisionTreeRegressor(max_depth=18, max_features=13, min_samples_split=13,
#                       random_state=42)

# %%
# Лучшая кодировка
best_model_preprocessor = randomized_search.best_estimator_['preprocessor']
best_model_preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('ohe',
#                                  Pipeline(steps=[('simpleImputer_ohe_NoneType',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('simpleImputer_ohe_str',
#                                                   SimpleImputer(missing_values=' ',
#                                                                 strategy='most_frequent')),
#                                                  ('ohe',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  ['dept', 'last_year_promo',
#                                   'last_ye...
# ...

# %%
# Объединим датасеты со входными признакими и с таргетом в один, а затем снова разделим их
# Это нужно, чтобы избежать несовпадения входных признаков и таргета в случае, 
# если наблюдения в каждом из датасетов находятся в разном порядке
final_job_satisfaction_rate = test_features.join(test_target_job_satisfaction_rate, how='left')
display(final_job_satisfaction_rate.head(),
        final_job_satisfaction_rate.shape)
# Out:
#              dept   level workload  employment_years last_year_promo  \
# id
# 485046  marketing  junior   medium                 2              no
# 686555         hr  junior   medium                 1              no
# 467458      sales  middle      low                 5              no
# 418655      sales  middle      low                 6              no
# 789145         hr  middle   medium                 5              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# 485046                   no                      5   28800
# 686555                   no                      4   30000
# 467458                   no                      4   19200
# 418655                   no                      4   19200
# 789145                   no                      5   40800
#
#         job_satisfaction_rate
# id
# 485046                   0.79
# 686555                   0.72
# 467458                   0.64
# 418655                   0.60
# ...

# %%
test_features = final_job_satisfaction_rate.drop('job_satisfaction_rate', axis=1)
test_target_job_satisfaction_rate = final_job_satisfaction_rate['job_satisfaction_rate']

X_test_encoded = best_model_preprocessor.transform(test_features)
y_test_predict = best_model.predict(X_test_encoded)

smape_value = smape_func(test_target_job_satisfaction_rate.values, y_test_predict)
print('Метрика лучшей модели на тестовой выборке:', smape_value)
# Out:
# Метрика лучшей модели на тестовой выборке: 13.882336944580182

# %% [markdown]
# Проверим модель на адекватность.

# %%
X_train_encoded = best_model_preprocessor.transform(X_train)

dummy_regressor = DummyRegressor(strategy='mean')
dummy_regressor.fit(X_train, y_train)

y_pred = dummy_regressor.predict(X_test_encoded)

# Оценка качества модели DummyRegressor
smape_dummy = smape_func(test_target_job_satisfaction_rate.values, y_pred)
print('Оценка качества модели DummyRegressor на тестовой выборке:', smape_dummy)
# Out:
# Оценка качества модели DummyRegressor на тестовой выборке: 38.26225790202237

# %% [markdown]
# Результат тестирования нашей модели на тестовой выборки лучше, чем результат константной модели, предсказывющей среднее на тренировочной выборке - значит, наша модель не бесполезна и усилия не напрасны.

# %% [markdown]
# ### Анализ важности признаков

# %% [markdown]
# Проведем анализ признаков с целью увеличения качества работы модели, согласно метрике SMAPE.

# %%
X_train_p = pd.DataFrame(
    best_model_preprocessor.fit_transform(X_train),
    columns=best_model_preprocessor.get_feature_names_out())

X_test_p = pd.DataFrame(
    best_model_preprocessor.transform(test_features),
    columns=best_model_preprocessor.get_feature_names_out()    
)

# %%
# Проведем анализ важности признаков
feature_importance = pd.DataFrame({'Feature': X_test_p.columns, 'Importance': best_model.feature_importances_})
feature_importance = feature_importance.sort_values(by='Importance', ascending=True)
sns.set_style('white')
feature_importance.plot(x='Feature', y='Importance', kind='barh', figsize=(10, 6))
plt.title(f'Анализ важности признаков', fontsize=16)
plt.ylabel('Признак', fontsize=14)
plt.xlabel('Важность', fontsize=14);

# %%
X_test_p.columns
# Out:
# Index(['ohe__dept_marketing', 'ohe__dept_purchasing', 'ohe__dept_sales',
#        'ohe__dept_technology', 'ohe__last_year_promo_yes',
#        'ohe__last_year_violations_yes', 'ord__level', 'ord__workload',
#        'num__employment_years', 'num__supervisor_evaluation', 'num__salary'],
#       dtype='object')

# %% [markdown]
# - сильное влияние на резулттаты работы модели оказывает признак 'supervisor_evaluation'.
# - признак 'dept' ('ohe__dept_sales', 'ohe__dept_technology', 'ohe__dept_marketing', 'ohe__dept_purchasing') мало значим для модели.

# %% [markdown]
# ## 1.7 Вывод

# %% [markdown]
# По итогу решения первой задачи можно скзать следующее:
# - было построено дерево решений, которое предсказывает уровень удовлетворённости сотрудника работой в компании. Оно было выбрано путем перебора нескольких вариаций моделей, гиперпараметров, а также способов кодировки данных.
# - значение метрики SMAPE на валидационной и тестовой выборках подходит под критерий успеха: SMAPE ≤ 15 на тестовой выборке.

# %% [markdown]
# ## Задача 2: предсказание увольнения сотрудника из компании

# %% [markdown]
# ## 2.1 Описание данных

# %% [markdown]
# Для этой задачи используются те же входные признаки, что и в предыдущей задаче. Однако целевой признак отличается: это quit — увольнение сотрудника из компании.

# %% [markdown]
# - Тренировочная выборка `train_quit.csv`
# - Входные признаки тестовой выборки те же, что и в прошлой задаче: `test_features.csv`
# - Целевой признак тестовой выборки: `test_target_quit.csv`

# %% [markdown]
# ## 2.2 Загрузка данных

# %%
train_quit = pd.read_csv('https://code.s3.yandex.net/datasets/train_quit.csv')
test_target_quit = pd.read_csv('https://code.s3.yandex.net/datasets/test_target_quit.csv')

# %%
data_overview([train_quit, test_target_quit])
# Out:
# ...
# Общая информация о датафрейме:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB
# None
# ****************************************************************************************************
# Статистическое описание числовых данных датафрейма:
# ...

# %% [markdown]
# ## 2.3 Предобработка данных

# %% [markdown]
# ### 2.3.1 Датафрейм train_quit

# %%
studying_dataframe(train_quit)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB
# None
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# ...

# %% [markdown]
# Изучив общую информацию о датафрейме, предварительно можно сказать, что пропуски в данных отсутсвуют, исходя из соответствия количества строк в каждом столбце общему количеству строк. Также во всех столбцах типы данных соответствуют содержащимся в них значениям.

# %% [markdown]
# Проверим на наличие дубликатов.

# %%
search_for_duplicates(train_quit, ['id'])
# Out:
# Количество ПОЛНЫХ явных дубликатов: 0
#
# Количество НЕПОЛНЫХ явных дубликатов: 0
#
# Проверка на неявные дубликаты:
# - Для dept: ['sales', 'purchasing', 'marketing', 'technology', 'hr']
# - Для level: ['middle', 'junior', 'sinior']
# - Для workload: ['high', 'medium', 'low']
# - Для last_year_promo: ['no', 'yes']
# - Для last_year_violations: ['no', 'yes']
# - Для quit: ['no', 'yes']

# %% [markdown]
# Дубликаты отсутствуют. Можно заметить опечатку в "sinior". Заменим на "senior".

# %%
train_quit.loc[train_quit['level'] == 'sinior', 'level'] = 'senior'

# Проверка
train_quit['level'].unique()
# Out:
# array(['middle', 'junior', 'senior'], dtype=object)

# %% [markdown]
# ### 2.3.2 Датафрейм test_target_quit

# %%
studying_dataframe(test_target_quit)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   int64
#  1   quit    2000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB
# None
#        id quit
# 0  999029  yes
# 1  372846   no
# 2  726767   no
# 3  490105   no
# 4  416898  yes

# %%
search_for_duplicates(test_target_quit, ['id'])
# Out:
# Количество ПОЛНЫХ явных дубликатов: 0
#
# Количество НЕПОЛНЫХ явных дубликатов: 0
#
# Проверка на неявные дубликаты:
# - Для quit: ['yes', 'no']

# %% [markdown]
# Дубликаты обнаружены не были.

# %%
# Сделаем значения столбца 'id' индексами
test_target_quit = test_target_quit.set_index('id')
test_target_quit.head()
# Out:
#        quit
# id
# 999029  yes
# 372846   no
# 726767   no
# 490105   no
# 416898  yes

# %% [markdown]
# ## 2.4 Исследовательский анализ данных

# %% [markdown]
# ### 2.4.1 Датафрейм  train_quit

# %%
# Сделаем значения столбца 'id' индексами
train_quit = train_quit.set_index('id')
train_quit.head()
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 723290       sales  middle     high                 2              no
# 814010       sales  junior   medium                 2              no
# 155091  purchasing  middle   medium                 5              no
# 257132       sales  junior   medium                 2              no
# 910140   marketing  junior   medium                 2              no
#
#        last_year_violations  supervisor_evaluation  salary quit
# id
# 723290                   no                      4   54000   no
# 814010                   no                      4   27600   no
# 155091                   no                      1   37200   no
# 257132                  yes                      3   24000  yes
# 910140                   no                      5   25200   no

# %%
que_col_names, cat_col_names = distribution_by_data_types(train_quit)
print(f'Количественные признаки: {que_col_names}\n\nКатегориальные признаки: {cat_col_names}')
# Out:
# Количественные признаки: ['employment_years', 'supervisor_evaluation', 'salary']
#
# Категориальные признаки: ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations', 'quit']

# %% [markdown]
# 'employment_years' и 'supervisor_evaluation' - дискретные признаки.

# %%
qua_cont_col_names = ['salary']
qua_dis_col_names = ['employment_years', 'supervisor_evaluation']
print(f'Количественные непрерывные признаки: {qua_cont_col_names}\n\nКоличественные дискретные признаки: {qua_dis_col_names}')
# Out:
# Количественные непрерывные признаки: ['salary']
#
# Количественные дискретные признаки: ['employment_years', 'supervisor_evaluation']

# %%
research_analysis(train_quit, qua_cont_col_names, qua_dis_col_names, cat_col_names, 'quit')
# Out:
# Описание данных для столбца 'salary':
# count     4000.000000
# mean     33805.800000
# std      15152.415163
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      96000.000000
# Name: salary, dtype: float64

# %% [markdown]
# Проведем анализ категориальных признаков для каждой категории сотрудников по-отдельности, чтобы выявить какие-то отличия.

# %%
# Для уволившихся 
for col in ['dept', 'level', 'workload']:
    research_categorical_signs(train_quit[train_quit['quit'] == 'yes'], col)

# %%
# Для уволившихся 
for col in ['dept', 'level', 'workload']:
    research_categorical_signs(train_quit[train_quit['quit'] == 'no'], col)

# %% [markdown]
# Изучив результаты исследовательского анализа датафрейма **train_quit**, можно сказать следующее:
# - `employment_years` — людей, работающих в компании около 1 года, больше количества людей с любой другой продолжительностью работы. Сотрудников, работающих более 10 лет, нет.
# - `supervisor_evaluation` — чаще всего сотрудники получают оценку 4 по пятибалльной шкале, реже 3 и 5, совсем редко 2 и 1.
# - `salary` — аналогично предыдущим, признак имеет нормальное распределение, но с положительной ассиметрией. Ежемесячная зарплата сотрудника в среднем составляет 33805, по гистограмме (медиаонное) около 30000. Можно заметить некоторое количество выбросов - скорее всего это сотрудники занимающие высокие/руководящие должности. В удалении нет необходимости, так как это реальные люди (реальные наблюдения), и вполне нормально что людей с такими должностями много меньше других сотрудников, а их зарплата выше. Модель должна будет уметь их учитывать. **Чаще уходят из компании сотрудники с зарплатой около 10000-35000. На вид тотальная неудовлетворенность оплатой труда и, возможно, получение оффера с большей зарплатой от другой компании.**
# - `dept` — отдел, в котором работает больше всего сотрудников - sales. За ним идет отдел technology с штатом работников, размер которого практически в два раза меньше sales. Меньше всего сотрудников в hr-отделе.
# - `level` — больше всего сотрудников с уровенем занимаемой должности junior и middle, меньше всего - sinior.
# - `workload` — сотрудников со средним (medium) уровнем загруженности больше всего, с высоким (high) меньше всего.
# - `last_year_promo` — согласно диаграмме, лишь единицы получили повышение за последний год.
# - `last_year_violations` — около 500 сотрудников нарушили трудовой договор за последний год, остальные 3500 являются добропорядочными работниками.
# - `quit` - целевой признак. Изучив столбчатую диаграмму целевого признака, мы можем точно сказать, что имеем дело с дисбалансом классов. К мажорному классу относятся по-прежнему работающие сотрудники, а к минорному - уволившиеся. В контексте данной задачи такое явление абсолютно нормально. Если бы было наоборот или хотя бы поровну, то возникал бы ряд вопросов об адекватности компании и ее добропорядочности по отношению к сотрудникам.

# %% [markdown]
# ### 2.4.2 Датафрейм test_features

# %% [markdown]
# Полноценный исследовательский анализ данного датафрейма был проведен в пункте 1.4.2. Теперь сравним статистические описания тренировочной выборки train_quit и тестовой test_features.

# %%
 train_quit.describe().T
# Out:
#                         count         mean           std      min      25%  \
# employment_years       4000.0      3.70150      2.541852      1.0      2.0
# supervisor_evaluation  4000.0      3.47475      1.004049      1.0      3.0
# salary                 4000.0  33805.80000  15152.415163  12000.0  22800.0
#
#                            50%      75%      max
# employment_years           3.0      6.0     10.0
# supervisor_evaluation      4.0      4.0      5.0
# salary                 30000.0  43200.0  96000.0

# %%
test_features.describe().T
# Out:
#                         count        mean           std      min      25%  \
# employment_years       2000.0      3.6665      2.537222      1.0      1.0
# supervisor_evaluation  2000.0      3.5265      0.996892      1.0      3.0
# salary                 2000.0  34066.8000  15398.436729  12000.0  22800.0
#
#                            50%      75%      max
# employment_years           3.0      6.0     10.0
# supervisor_evaluation      4.0      4.0      5.0
# salary                 30000.0  43200.0  96000.0

# %% [markdown]
# Статистические описания тренировочной и тестовой выборок похожи - это хороший знак для модели машинного обучения. Похожесть этих описаний указывает на то, что данные, на которых модель обучается (тренировочная выборка), и данные, на которых модель тестируется (тестовая выборка), взяты из одного и того же распределения. А также означает, что оба эти датасета были собраны в одинаковых условиях, то есть никаких измненений в исследуемом процессе не произошло.

# %% [markdown]
# ## 2.5 Корреляционный анализ

# %% [markdown]
# ### Общий

# %%
# Создаем список с наименованиями непрерывных признаков
interval_col_names, cat_col_names = distribution_by_data_types(train_quit)
interval_col_names
# Out:
# ['employment_years', 'supervisor_evaluation', 'salary']

# %% [markdown]
# 'employment_years' и 'supervisor_evaluation' - дискретные признаки.

# %%
interval_col_names.remove('employment_years')
interval_col_names.remove('supervisor_evaluation')
interval_col_names
# Out:
# ['salary']

# %%
# Рассчитаем корреляционную матрицу
phik_overview = phik_matrix(train_quit, interval_cols=interval_col_names)

# Визуализируем корреляционную матрицу
plot_correlation_matrix(phik_overview.values,
                        x_labels=phik_overview.columns,
                        y_labels=phik_overview.index,
                        vmin=0, vmax=1, color_map='BuPu',
                        title=r'correlation $\phi_K$',
                        fontsize_factor=1.5,
                        figsize=(20, 15))

# %% [markdown]
# Изучив корреляционную матрицу, можно выделить следующее:
# - целевой признак `quit` имеет **среднюю** линейную зависимость от признака **employment_years** и от **salary**.

# %% [markdown]
# ### Для уволившихся сотрудников

# %%
# Рассчитаем корреляционную матрицу
phik_overview = phik_matrix(train_quit[train_quit['quit'] == 'yes'].drop('quit', axis=1), interval_cols=interval_col_names)

# Визуализируем корреляционную матрицу
plot_correlation_matrix(phik_overview.values,
                        x_labels=phik_overview.columns,
                        y_labels=phik_overview.index,
                        vmin=0, vmax=1, color_map='PuBu',
                        title=r'correlation $\phi_K$',
                        fontsize_factor=1.5,
                        figsize=(20, 15))

# %% [markdown]
# ### Для работающих сотрудников

# %%
# Рассчитаем корреляционную матрицу
phik_overview = phik_matrix(train_quit[train_quit['quit'] == 'no'].drop('quit', axis=1), interval_cols=interval_col_names)

# Визуализируем корреляционную матрицу
plot_correlation_matrix(phik_overview.values,
                        x_labels=phik_overview.columns,
                        y_labels=phik_overview.index,
                        vmin=0, vmax=1, color_map='PuRd',
                        title=r'correlation $\phi_K$',
                        fontsize_factor=1.5,
                        figsize=(20, 15))

# %% [markdown]
# **Общий вывод**:
# Можно выделяить следущее cходство между корреляционной матрицей построенной для датасета не разбитого по таргету и для двух других, отвечающих за анлиз датасетов для каждого отдельного значения целевого признака: объем мультиколлинеарных зависимостей одинаков:
# - высокая и средняя линейные зависимости, соответственно, между **salary** и **workload** и **level**, то есть зарплата тем выше, чем выше уровень занимаемой должности сотрудника и уровень его загруженности.
# - также наблюдается средняя линейная зависимость между **level** и **employment_years** и **workload**, то есть чем дольше сотрудник работает в компании и чем более сложную работу он делает, тем более высокую должность он занимает.

# %% [markdown]
# ## 2.6 Портрет уволившегося сотрудника

# %% [markdown]
# Выполним исследовательский анализ для уволившихся сотрудников.

# %%
que_col_names, cat_col_names = distribution_by_data_types(train_quit.drop('quit', axis=1))
print(f'Количественные признаки: {que_col_names}\n\nКатегориальные признаки: {cat_col_names}')
# Out:
# Количественные признаки: ['employment_years', 'supervisor_evaluation', 'salary']
#
# Категориальные признаки: ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']

# %% [markdown]
# 'employment_years' и 'supervisor_evaluation' - дискретные признаки.

# %%
qua_cont_col_names = ['salary']
qua_dis_col_names = ['employment_years', 'supervisor_evaluation']
print(f'Количественные непрерывные признаки: {qua_cont_col_names}\n\nКоличественные дискретные признаки: {qua_dis_col_names}')
# Out:
# Количественные непрерывные признаки: ['salary']
#
# Количественные дискретные признаки: ['employment_years', 'supervisor_evaluation']

# %%
qua_dis_col_names + cat_col_names
# Out:
# ['employment_years',
#  'supervisor_evaluation',
#  'dept',
#  'level',
#  'workload',
#  'last_year_promo',
#  'last_year_violations']

# %%
# Анализ категориальных и дискретных признаков
for i in qua_dis_col_names + cat_col_names:
    plt.figure(figsize=(10, 6))  
    train_quit.loc[train_quit['quit'] == 'yes', i].value_counts().plot.pie(autopct='%1.1f%%')
    plt.title(f'Круговая диаграмма для {i}')
    plt.show()

# %%
# Анализ salary
research_quantitative_continuous_signs(train_quit, 'salary', 'quit')
# Out:
# Описание данных для столбца 'salary':
# count     4000.000000
# mean     33805.800000
# std      15152.415163
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      96000.000000
# Name: salary, dtype: float64

# %% [markdown]
# Проверим гипотезу о том, что зарплата уволившихся сотрудников меньше, чем у сотрудников по-прежнему работающих в компании:
#
# Нулевая гипотеза: среднее значение зарплаты уволившихся сотрудников равно среднему значению зарплаты по-прежнему работающих сотрудников.
#
# Альтернативная гипотеза: среднее значение зарплаты уволившихся сотрудников меньше, чем среднее значение зарплаты работающих по-прежнему сотрудников.

# %%
alpha = 0.05

train_quit_yes = train_quit.loc[train_quit['quit'] == 'yes']
train_quit_no = train_quit.loc[train_quit['quit'] == 'no'].sample(n=train_quit_yes.shape[0])

results = st.ttest_ind(train_quit_yes['salary'], train_quit_no['salary'], alternative='less')

display(f'p-value: {results.pvalue}')

if results.pvalue < alpha:
    display('Отвергаем нулевую гипотезу')
else:
    display('Нет оснований отвергнуть нулевую гипотезу')
# Out:
# 'p-value: 7.085771304541122e-125'
# 'Отвергаем нулевую гипотезу'

# %% [markdown]
# Таким образом, можно составить портрет сотрудника, который более склонен принять решение уволиться:
# - уровень занимаемой должности - junior
# - уровень загруженности сотрудника - low/medium
# - длительность работы в компании 1 год
#
# Рекордное количество сотрудников уволняются после первого года работы. Далее, с увеличением продолжительности работы в компании, все меньше и меньше людей ее покидают. После семи лет этот процесс останавливается - люди остаются работать. Возможно, в первые три года, то есть на ранних стадиях, понимая, что эта компания им не подходит люди увольняются. А после трех лет, пройдя стадию привыкания к коллективу, рабочему месту и обязанностями, сотрудники все реже и реже принимают решение об уходе.
# - оценка качества работы сотрудника, которую дал руководитель - 3
#
# Чаще увольняются те, работа которых оценивается на 3. Можно предположить, что они уходят в другие компании, где, как они считают, их будут ценить больше, и они наконец-то дождуться высокой оценки своего труда, которую, по их мнению, они заслуживают.
# - среднее значение зарплаты уволившихся сотрудников меньше, чем среднее значение зарплаты работающих по-прежнему сотрудников.
# - сотрудник работал в отделе sales или technology
# - за год работы так и не дождался повышения

# %% [markdown]
# Далее проверим оказывает ли какое-то влияние уровень удовлетворённости сотрудника работой в компании на увольнение.

# %% [markdown]
# Визуализируем и сравним распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников.

# %% [markdown]
# Объединим датафреймы test_features, test_target_job_satisfaction_rate и test_target_quit.

# %%
final = test_features.join(test_target_job_satisfaction_rate, how='left')
final.head()
# Out:
#              dept   level workload  employment_years last_year_promo  \
# id
# 485046  marketing  junior   medium                 2              no
# 686555         hr  junior   medium                 1              no
# 467458      sales  middle      low                 5              no
# 418655      sales  middle      low                 6              no
# 789145         hr  middle   medium                 5              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# 485046                   no                      5   28800
# 686555                   no                      4   30000
# 467458                   no                      4   19200
# 418655                   no                      4   19200
# 789145                   no                      5   40800
#
#         job_satisfaction_rate
# id
# 485046                   0.79
# 686555                   0.72
# 467458                   0.64
# 418655                   0.60
# ...

# %%
final = final.join(test_target_quit, how='left')
final.head()
# Out:
#              dept   level workload  employment_years last_year_promo  \
# id
# 485046  marketing  junior   medium                 2              no
# 686555         hr  junior   medium                 1              no
# 467458      sales  middle      low                 5              no
# 418655      sales  middle      low                 6              no
# 789145         hr  middle   medium                 5              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# 485046                   no                      5   28800
# 686555                   no                      4   30000
# 467458                   no                      4   19200
# 418655                   no                      4   19200
# 789145                   no                      5   40800
#
#         job_satisfaction_rate quit
# id
# 485046                   0.79   no
# 686555                   0.72   no
# 467458                   0.64   no
# ...

# %%
research_quantitative_continuous_signs(final, 'job_satisfaction_rate', 'quit')
# Out:
# Описание данных для столбца 'job_satisfaction_rate':
# count    2000.00000
# mean        0.54878
# std         0.22011
# min         0.03000
# 25%         0.38000
# 50%         0.58000
# 75%         0.72000
# max         1.00000
# Name: job_satisfaction_rate, dtype: float64

# %% [markdown]
# По гистограмме можно сказать, что чаще всего увольняются сотрудники, уровень удовлетворённости работой в компании которых составляет 0.4. Работающие сотрудники наиболее удовлетворены компанией.

# %%
# Создаем список с наименованиями непрерывных признаков
interval_col_names, cat_col_names = distribution_by_data_types(final)
interval_col_names
# Out:
# ['employment_years',
#  'supervisor_evaluation',
#  'salary',
#  'job_satisfaction_rate']

# %% [markdown]
# 'employment_years' и 'supervisor_evaluation' - дискретные признаки.

# %%
interval_col_names.remove('employment_years')
interval_col_names.remove('supervisor_evaluation')
interval_col_names
# Out:
# ['salary', 'job_satisfaction_rate']

# %%
# Рассчитаем корреляционную матрицу
phik_overview = phik_matrix(final, interval_cols=interval_col_names)

# Визуализируем корреляционную матрицу
plot_correlation_matrix(phik_overview.values,
                        x_labels=phik_overview.columns,
                        y_labels=phik_overview.index,
                        vmin=0, vmax=1, color_map='BuPu',
                        title=r'correlation $\phi_K$',
                        fontsize_factor=1.5,
                        figsize=(20, 15))

# %% [markdown]
# Прослеживает **средняя** линейная зависимость между **quit** И **job_satisfaction_rate**. Обучим модель, предсказывающую увольнение сотрудника, добавив новый признак.

# %% [markdown]
# ## 2.7 Добавление нового признака

# %% [markdown]
# Добавим новый признак **job_satisfaction_rate** в **train_quit**. Для этого предскажем его с помощью полученной модели.

# %%
X_test_encoded = best_model_preprocessor.transform(train_quit)
y_test_predict = best_model.predict(X_test_encoded)

train_quit['job_satisfaction_rate'] = y_test_predict
train_quit.head()
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 723290       sales  middle     high                 2              no
# 814010       sales  junior   medium                 2              no
# 155091  purchasing  middle   medium                 5              no
# 257132       sales  junior   medium                 2              no
# 910140   marketing  junior   medium                 2              no
#
#        last_year_violations  supervisor_evaluation  salary quit  \
# id
# 723290                   no                      4   54000   no
# 814010                   no                      4   27600   no
# 155091                   no                      1   37200   no
# 257132                  yes                      3   24000  yes
# 910140                   no                      5   25200   no
#
#         job_satisfaction_rate
# id
# 723290               0.648000
# 814010               0.846364
# 155091               0.340000
# ...

# %%
train_quit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 723290 to 853842
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   dept                   4000 non-null   object
#  1   level                  4000 non-null   object
#  2   workload               4000 non-null   object
#  3   employment_years       4000 non-null   int64
#  4   last_year_promo        4000 non-null   object
#  5   last_year_violations   4000 non-null   object
#  6   supervisor_evaluation  4000 non-null   int64
#  7   salary                 4000 non-null   int64
#  8   quit                   4000 non-null   object
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 472.8+ KB

# %% [markdown]
# ## 2.8 Обучение модели

# %% [markdown]
# Перед нами стоит задача бинарной классификации, так как целевой признак 'quit' принимает лишь два значения: «yes» или «no». Также не стоит забывать про дисбаланс классов, который нам нужно будет учесть при разбиение датафрейма на тренировочные и тестовые выборки.

# %% [markdown]
# ### Подготовка данных

# %%
X_train = train_quit.drop('quit', axis=1)
y_train = train_quit['quit']

# %% [markdown]
# Закодируем целевой признак с помощью LabelEncoder.

# %%
label_encoder = LabelEncoder()

y_train = label_encoder.fit_transform(y_train)

# Проверка
pred_classes = [0, 1]
print(label_encoder.inverse_transform(pred_classes))
# Out:
# ['no' 'yes']

# %%
num_columns, cat_columns = distribution_by_data_types(train_quit)
print(f'Количественные признаки: {num_columns}\n\nКатегориальные признаки: {cat_columns}')
# Out:
# Количественные признаки: ['employment_years', 'supervisor_evaluation', 'salary', 'job_satisfaction_rate']
#
# Категориальные признаки: ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations', 'quit']

# %% [markdown]
# - Количественные признаки будут закодированы с помощью StandardScaler/MinMaxScaler/RobustScaler/без кодировки
# - Категориальные признаки будут закодированы следующим образом:
#   - 'level' и'workload' с помощью OrdinalEncoder(), так как данные признаки являются ранговыми.
#   - Остальные категориальные признаки будут кодироваться с помощью OneHotEncoding().

# %%
# Разделим категориальные признаки в зависимости от способа кодирования
ohe_columns = ['dept', 'last_year_promo', 'last_year_violations']
ord_columns = ['level', 'workload']

# %%
display(num_columns,
       ohe_columns,
       ord_columns)
# Out:
# ['employment_years',
#  'supervisor_evaluation',
#  'salary',
#  'job_satisfaction_rate']
# ['dept', 'last_year_promo', 'last_year_violations']
# ['level', 'workload']

# %% [markdown]
# - Подходящей для задачи метрикой является **ROC_AUC**, так как она **наиболее устойчива при проверке качества модели, которая была обучена на несбалансированных данных**, а также отражает **способность модели определять каждый отдельный класс независимо от порога вероятности**.

# %% [markdown]
# ### Использование пайплайна

# %%
# создаём пайплайн для подготовки признаков из списка ohe_columns: заполнение пропусков и OHE-кодирование
# SimpleImputer + OHE
ohe_pipe = Pipeline(
    [('simpleImputer_ohe_NoneType', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('simpleImputer_ohe_str', SimpleImputer(missing_values=' ', strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
    ]
    )

# создаём пайплайн для подготовки признаков из списка ord_columns: заполнение пропусков и Ordinal-кодирование
# SimpleImputer + OE
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[
                    ['junior', 'middle', 'sinior'], 
                    ['low', 'medium', 'high'] 
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# создаём итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']   
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']  
    },
    
    # словарь для модели SVC()
    {
        'models': [SVC(random_state=RANDOM_STATE, probability=True)],
        'models__C': range(1, 2),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    }
]

# %%
randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)
randomized_search.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print('Метрика лучшей модели, полученная при кросс-валидации:', randomized_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe_NoneType',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('simpleImputer_ohe_str',
#                                                                    SimpleImputer(missing_values=' ',
#                                                                                  strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
# ...

# %% [markdown]
# ### Рассчет метрики ROC_AUC на тестовой выборке

# %%
final.head()
# Out:
#              dept   level workload  employment_years last_year_promo  \
# id
# 485046  marketing  junior   medium                 2              no
# 686555         hr  junior   medium                 1              no
# 467458      sales  middle      low                 5              no
# 418655      sales  middle      low                 6              no
# 789145         hr  middle   medium                 5              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# 485046                   no                      5   28800
# 686555                   no                      4   30000
# 467458                   no                      4   19200
# 418655                   no                      4   19200
# 789145                   no                      5   40800
#
#         job_satisfaction_rate quit
# id
# 485046                   0.79   no
# 686555                   0.72   no
# 467458                   0.64   no
# ...

# %%
# Лучшая модель
best_model = randomized_search.best_estimator_.named_steps['models']
best_model
# Out:
# LogisticRegression(C=4, penalty='l1', random_state=42, solver='liblinear')

# %%
# Лучшая кодировка
best_model_preprocessor = randomized_search.best_estimator_['preprocessor']
best_model_preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('ohe',
#                                  Pipeline(steps=[('simpleImputer_ohe_NoneType',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('simpleImputer_ohe_str',
#                                                   SimpleImputer(missing_values=' ',
#                                                                 strategy='most_frequent')),
#                                                  ('ohe',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  ['dept', 'last_year_promo',
#                                   'last_ye...
# ...

# %%
test_features = final.drop('quit', axis=1)
test_target_quit = final['quit']

X_test_encoded = best_model_preprocessor.transform(test_features)
test_target_quit = label_encoder.transform(test_target_quit)

y_test_predict = best_model.predict_proba(X_test_encoded)[:, 1]

print('Метрика лучшей модели на тестовой выборке:', roc_auc_score(test_target_quit, y_test_predict))
# Out:
# Метрика лучшей модели на тестовой выборке: 0.910810417037081

# %% [markdown]
# Достинуто требуемое качество модели AUC-ROC >= 0.91.

# %% [markdown]
# Проверим модель на адекватность

# %%
X_train_encoded = best_model_preprocessor.transform(X_train)

dummy_regressor = DummyRegressor(strategy='mean')
dummy_regressor.fit(X_train, y_train)

y_pred = dummy_regressor.predict(X_test_encoded)

# Оценка качества модели DummyRegressor
print('Оценка качества модели DummyRegressor на тестовой выборке:', roc_auc_score(test_target_quit, y_pred))
# Out:
# Оценка качества модели DummyRegressor на тестовой выборке: 0.5

# %% [markdown]
# Результат тестирования нашей модели на тестовой выборки лучше, чем результат константной модели, предсказывющей среднее на тренировочной выборке - значит, наша модель не бесполезна и усилия не напрасны.

# %% [markdown]
# ### Анализ важности признаков

# %%
X_train_p = pd.DataFrame(
    best_model_preprocessor.fit_transform(X_train),
    columns=best_model_preprocessor.get_feature_names_out())

X_test_p = pd.DataFrame(
    best_model_preprocessor.transform(test_features),
    columns=best_model_preprocessor.get_feature_names_out()    
)

# %%
explainer = shap.LinearExplainer(best_model, X_test_p)
shap_values = explainer(X_test_p)

plt.figure(figsize=(30, 30))

shap.summary_plot(shap_values, X_test_p, cmap='coolwarm', show=False)

# Получение текущих объектов осей графика
ax = plt.gca()

ax.tick_params(labelsize=14)  
ax.set_xlabel("Важность признака", fontsize=14) 
ax.set_title('Анализ важности признаков', fontsize=16) 

# Получение объекта цветовой шкалы
cb_ax = plt.gcf().axes[1]

# Настройка параметров цветовой шкалы
cb_ax.tick_params(labelsize=15)  # Установка размера меток на цветовой шкале
cb_ax.set_ylabel("Значение признака", fontsize=20) 

plt.show()

# %%
X_test_p.columns
# Out:
# Index(['ohe__dept_marketing', 'ohe__dept_purchasing', 'ohe__dept_sales',
#        'ohe__dept_technology', 'ohe__last_year_promo_yes',
#        'ohe__last_year_violations_yes', 'ord__level', 'ord__workload',
#        'num__employment_years', 'num__supervisor_evaluation', 'num__salary',
#        'num__job_satisfaction_rate'],
#       dtype='object')

# %% [markdown]
# По результатам анализа важности признаков мы можем сказать следующее:
# - признаки 'ohe__last_year_violations_yes', 'ord__workload', 'ohe__dept_purchasing', 'ohe__dept_sales' мало значимы для модели;
# - сильнее всего влияют на целевой признак 'num__employment_years', 'num__job_satisfaction_rate' и 'num__salary'. Они также являются одними из самых полезных, так как оказывают **наиболее сильное влияние именно при определении работающих сотрудников, то есть, чем дольше длительность работы в компании и больше зарплата, тем вероятнее, что человек по-прежнему работает, а также чем меньше уровень удовлетворенности сотрудника работой, тем вероятнее его увольнение.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Перед нами стояло две задачи: первая — построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика, вторая задача — построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании. Тем самым мы сможем предсказать и предотвратить отток сотрудников, то есть избежать внезапных увольнений, несущих в себе риски для компании, особенно если уходит важный сотрудник.
#
# В ходе выполнения работы была выполнена предобработка данных: изучена общая информация о каждом из пяти датасетов, осуществлена проверка на полные и неполные явные и неявные дубликаты, а также проверено соответствие стиля написания столбцов и данных единому формату.
#
# Затем был проведен исследовательский анализ, в ходе которого были рассмотрены выбросы и артефакты, а также изучено распределение данных. Сопоставлены статистические описания тренировочных и тестовых датафреймов. После этого последовал корреляционный анализ данных. По итогу были сделаны следующие выводы:
# Изучив результаты исследовательского анализа, можно сказать следующее:
# - `employment_years` — людей, работающих в компании около 1 года, больше количества людей с любой другой продолжительностью работы. Сотрудников, работающих более 10 лет, нет. **Рекордное количество сотрудников уволняются после первого года работы. Далее, с увеличением продолжительности работы в компании, все меньше и меньше людей ее покидают. После семи лет этот процесс останавливается - люди остаются работать. Возможно, в первые три года, то есть на ранних стадиях, понимая, что эта компания им не подходит люди увольняются. А после трех лет, пройдя стадию привыкания к коллективу, рабочему месту и обязанностями, сотрудники все реже и реже принимают решение об уходе.**
# - `supervisor_evaluation` — чаще всего сотрудники получают оценку 4 по пятибалльной шкале, реже 3 и 5, совсем редко 2 и 1. Сотрудники, работа которых была оценена на 4, увольняются гораздо реже других. **Чаще увольняются те, работа которых оценивается на 3. Можно предположить, что они уходят в другие компании, где, как они считают, их будут ценить больше, и они наконец-то дождуться высокой оценки своего труда, которую, по их мнению, они заслуживают.**
# - `salary` — аналогично предыдущим, признак имеет нормальное распределение, но с положительной ассиметрией. Ежемесячная зарплата сотрудника в среднем составляет 33805, по гистограмме (медиаонное) около 30000. Можно заметить некоторое количество выбросов - скорее всего это сотрудники занимающие высокие/руководящие должности. В удалении нет необходимости, так как это реальные люди (реальные наблюдения), и вполне нормально что людей с такими должностями много меньше других сотрудников, а их зарплата выше. Модель должна будет уметь их учитывать. **Чаще уходят из компании сотрудники с зарплатой около 10000-35000. На вид тотальная неудовлетворенность оплатой труда и, возможно, получение оффера с большей зарплатой от другой компании.**
# - `dept` — отдел, в котором работает больше всего сотрудников - sales. За ним идет отдел technology с штатом работников, размер которого практически в два раза меньше sales. Меньше всего сотрудников в hr-отделе.
# - `level` — больше всего сотрудников с уровенем занимаемой должности junior и middle, меньше всего - sinior. **Среди уволившихся преобладают работник уровня junior.**
# - `workload` — сотрудников со средним (medium) уровнем загруженности больше всего, с высоким (high) меньше всего. **Чаще увольняются люди с уровнем загруженности 'low' и 'medium'.**
# - `last_year_promo` — согласно диаграмме, лишь единицы получили повышение за последний год.
# - `last_year_violations` — около 500 сотрудников нарушили трудовой договор за последний год, остальные 3500 являются добропорядочными работниками.
# - `quit` - целевой признак. Изучив столбчатую диаграмму целевого признака, мы можем точно сказать, что имеем дело с дисбалансом классов. К мажорному классу относятся по-прежнему работающие сотрудники, а к минорному - уволившиеся. В контексте данной задачи такое явление абсолютно нормально. Если бы было наоборот или хотя бы поровну, то возникал бы ряд вопросов об адекватности компании и ее добропорядочности по отношению к сотрудникам.
#
# Изучив корреляционную матрицу, можно выделить следующее:
# - целевой признак `job_satisfaction_rate` имеет **сильную** линейную зависимость от признака **supervisor_evaluation**. Коэффициент корреляции положительный, то есть чем выше оценка сотрудника, которую дал руководитель, тем выше уровень удовлетворенности сотрудника.
# - целевой признак `quit` имеет **среднюю** линейную зависимость от признака **employment_years** и от **salary**.
# - также была обнаружена мультиколлинеарность в каждом из рассматриваемых датасетов (в отчете можно ознакомиться подробнее), однако она превышала грань дозволенного, то есть коэффициент корреляции не отражал очень сильную зависимость, и в удалении зависимых входных признаков датасет не нуждался.
#
# По итогу проведенного исследовательского анализа был охарактеризован портрет уволившегося сотрудника:
# - уровень занимаемой должности - junior
# - уровень загруженности сотрудника - low/medium
# - длительность работы в компании 1 год
#
# Рекордное количество сотрудников уволняются после первого года работы. Далее, с увеличением продолжительности работы в компании, все меньше и меньше людей ее покидают. После семи лет этот процесс останавливается - люди остаются работать. Возможно, в первые три года, то есть на ранних стадиях, понимая, что эта компания им не подходит люди увольняются. А после трех лет, пройдя стадию привыкания к коллективу, рабочему месту и обязанностями, сотрудники все реже и реже принимают решение об уходе.
# - оценка качества работы сотрудника, которую дал руководитель - 3
#
# Чаще увольняются те, работа которых оценивается на 3. Можно предположить, что они уходят в другие компании, где, как они считают, их будут ценить больше, и они наконец-то дождуться высокой оценки своего труда, которую, по их мнению, они заслуживают.
# - среднее значение зарплаты уволившихся сотрудников меньше, чем среднее значение зарплаты работающих по-прежнему сотрудников.
# - сотрудник работал в отделе sales или technology
# - за год работы так и не дождался повышения
#
# Далее былы построены две модели: дерево решений и линейная модель , которые решили поставленные перед нами задачи. Они были выбраны путем перебора нескольких вариаций моделей, гиперпараметров, а также способов кодировки данных, соответсвующих конкретной из рассматриваемых задач. Метрики качества каждой из модели достигли успеха. По итогу анализа важности признаков было выявлено следующее:
# - Для модели решения задачи регресии (задачи 1):
#   - сильное влияние на резулттаты работы модели оказывает признак 'supervisor_evaluation'.
#   - признак 'dept' ('ohe__dept_sales', 'ohe__dept_technology', 'ohe__dept_marketing', 'ohe__dept_purchasing') мало значим для модели.
# - Для модели решения задачи классификации (задачи 2):
#   - признаки 'ohe__last_year_violations_yes', 'ord__workload', 'ohe__dept_purchasing', 'ohe__dept_sales' мало значимы для модели;
#   - сильнее всего влияют на целевой признак 'num__employment_years', 'num__job_satisfaction_rate' и 'num__salary'. Они также являются одними из самых полезных, так как оказывают **наиболее сильное влияние именно при определении работающих сотрудников, то есть, чем дольше длительность работы в компании и больше зарплата, тем вероятнее, что человек по-прежнему работает, а также чем меньше уровень удовлетворенности сотрудника работой, тем вероятнее его увольнение.
#
# Рекомендации:
# - предпринять какие-либо меры по введению "завлекающих" условий. Предоставить корпоративные скидки, оплату питания, компенсацию съема жилья (если сотрудник приехал из другого города специально для работы в компании), возможность заниматься спортом, страховой полис, возможно работать удаленно.
# - возможно, стоило бы сильнее нагружать специалистов с текущим уровнем low/medium. Не исключено, что их увольнения связаны с ограничением возможностей в реализации себя и своих идей, возможно, они получают лишь рутинные неинтресные задачи, никак не способствующие профессиональному развитию.
# - ввести ежегодную индексацию заработной платы
# - создать систему KPI, этот и предпоследний пункты должны мотивировать junior специалистов работать более одного года и продолжать развиваться внутри компании
